# %% [markdown]
# **Name: Pranav Nivrutti Neharkar**
#
# LGM VIP: Data Science Internship
#
# Language-Python
#
#  4.Iris Flower Classification
#
# Dataset-http://archive.ics.uci.edu/ml/datasets/Iris

# %%
import io # io Library used for various input and ouput operations
import numpy as np # numpy library used doing various operations on arrays
import pandas as pd # pandas library used for doing statstical calculations
import seaborn as sns # seaborn library is also used to interpreting the data in variousgraphs
from google.colab import files # this library used for dealing with files
import matplotlib.pyplot as plt # Matplotlib library is used for interpreting data in various graphs
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3a28d264-98b7-471d-b7a1-3fdcc4d3e462" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a28d264-98b7-471d-b7a1-3fdcc4d3e462">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(io.BytesIO(uploaded['iris.csv'])) #Reading the csv file in data
df.head() #Head is used to show top 5 rows of the data
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df['sepal.length'].hist()
# Out:
# <Axes: >

# %%
df['sepal.width'].hist()
# Out:
# <Axes: >

# %%
df['petal.length'].hist()
# Out:
# <Axes: >

# %%
df['petal.width'].hist()
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
l = ['Versicolor', 'Setosa', 'Virginica']
s = [50,50,50]
ax.pie(s, labels = l,autopct='%1.2f%%')
plt.show()

# %%
sns.pairplot(df)

# %%
from matplotlib import pyplot
df.plot(kind='box', subplots=True, layout=(3,2), sharex=False, sharey=False, figsize=(8,12))
pyplot.show()

# %%
colors = ['red', 'orange', 'blue']
variety = ['Iris-virginica','Iris-versicolor','Iris-setosa']

# %%
for i in range(3):
    x = df[df['variety'] == variety[i]]
    plt.scatter(x['sepal.length'], x['sepal.width'], c = colors[i], label=variety[i])
plt.xlabel("sepal.length")
plt.ylabel("sepal.width")
plt.legend()

# %%
for i in range(3):
    x = df[df['variety'] == variety[i]]
    plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], c = colors[i], label=variety[i])
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PetalLengthCm'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x[''PetalLengthCm'], x['petal_length'], c = colors[i], label=species[i])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()
